# %%
import pandas as pd

# %%
df = pd.read_parquet('data/channels/2025-05-14_channel_data.parquet')
df
# Out:
#                  channel_id channel_name subscribers  total_views video_count
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA      MrBeast   394000000  82521775256         870

# %%
df = pd.read_parquet('data/playlists/2025-05-14_playlist_data.parquet')
df
# Out:
#                           playlist_id        playlist_title  \
# 0  PLoSWVnSA9vG8hI-SUpAimvYJrPh-PRRvp           Stay to Win
# 1  PLoSWVnSA9vG_s-XT40oPKF0iWFGw8pOp2          Philanthropy
# 2  PLoSWVnSA9vG8SK6-_45PAu6RVTaP1zXHf                7 Days
# 3  PLoSWVnSA9vG_PuIrGMfUtJ2wwKSUb2CFd             $1 vs $$$
# 4  PLoSWVnSA9vG9hJNdgr-81MG59EYT9eEYn  Most Popular Uploads
#
#                  channel_id  video_count
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA            4
# 1  UCX6OQ3DkcsbYNE6H8uQQuVA            8
# 2  UCX6OQ3DkcsbYNE6H8uQQuVA            7
# 3  UCX6OQ3DkcsbYNE6H8uQQuVA            9
# 4  UCX6OQ3DkcsbYNE6H8uQQuVA           25

# %%
df = pd.read_parquet('data/videos/2025-05-14_video_data.parquet')
df
# Out:
#        video_id                                        video_title  \
# 0   UPrkC1LdlLY   Survive 100 Days In Nuclear Bunker, Win $500,000
# 1   U_LlX4t0A9I    $10,000 Every Day You Survive In The Wilderness
# 2   9RhWXPcKBI8             Survive 100 Days Trapped, Win $500,000
# 3   tnTPaLOaHz8   $10,000 Every Day You Survive In A Grocery Store
# 4   SM66GDRyIVY                   I Helped 2,000 People Walk Again
# 5   KkCXLABwHP0             I Built 100 Houses And Gave Them Away!
# 6   lOKASgtr6kU                        I Saved 100 Dogs From Dying
# 7   mwKJfNYwvm8                        I Built 100 Wells In Africa
# 8   WTOm65IZneg          1,000 Deaf People Hear For The First Time
# 9   TJ2ifmkGGus          1,000 Blind People See For The First Time
# 10  cV2gBU6hKfY     I Cleaned The World’s Dirtiest Beach #TeamSeas
# 11  HPJKxAhLw5I  Planting 20,000,000 Trees, My Biggest Project ...
# 12  bn0Kh9c4Zv4               7 Days Exploring An Underground City
# ...
