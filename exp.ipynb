# %%
import pandas as pd

# %%
df = pd.read_parquet('data/channels/2025-05-14_channel_data.parquet')
df
# Out:
#                  channel_id channel_name subscribers  total_views video_count
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA      MrBeast   394000000  82521775256         870

# %%
df = pd.read_parquet('data/playlists/2025-05-14_playlist_data.parquet')
df
# Out:
#                           playlist_id        playlist_title  \
# 0  PLoSWVnSA9vG8hI-SUpAimvYJrPh-PRRvp           Stay to Win
# 1  PLoSWVnSA9vG_s-XT40oPKF0iWFGw8pOp2          Philanthropy
# 2  PLoSWVnSA9vG8SK6-_45PAu6RVTaP1zXHf                7 Days
# 3  PLoSWVnSA9vG_PuIrGMfUtJ2wwKSUb2CFd             $1 vs $$$
# 4  PLoSWVnSA9vG9hJNdgr-81MG59EYT9eEYn  Most Popular Uploads
#
#                  channel_id  video_count
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA            4
# 1  UCX6OQ3DkcsbYNE6H8uQQuVA            8
# 2  UCX6OQ3DkcsbYNE6H8uQQuVA            7
# 3  UCX6OQ3DkcsbYNE6H8uQQuVA            9
# 4  UCX6OQ3DkcsbYNE6H8uQQuVA           25

# %%
df = pd.read_parquet('data/videos/2025-05-14_video_data.parquet')
df
# Out:
#        video_id                                        video_title  \
# 0   UPrkC1LdlLY   Survive 100 Days In Nuclear Bunker, Win $500,000
# 1   U_LlX4t0A9I    $10,000 Every Day You Survive In The Wilderness
# 2   9RhWXPcKBI8             Survive 100 Days Trapped, Win $500,000
# 3   tnTPaLOaHz8   $10,000 Every Day You Survive In A Grocery Store
# 4   SM66GDRyIVY                   I Helped 2,000 People Walk Again
# 5   KkCXLABwHP0             I Built 100 Houses And Gave Them Away!
# 6   lOKASgtr6kU                        I Saved 100 Dogs From Dying
# 7   mwKJfNYwvm8                        I Built 100 Wells In Africa
# 8   WTOm65IZneg          1,000 Deaf People Hear For The First Time
# 9   TJ2ifmkGGus          1,000 Blind People See For The First Time
# 10  cV2gBU6hKfY     I Cleaned The World’s Dirtiest Beach #TeamSeas
# 11  HPJKxAhLw5I  Planting 20,000,000 Trees, My Biggest Project ...
# 12  bn0Kh9c4Zv4               7 Days Exploring An Underground City
# ...

# %%
df = pd.read_parquet('data/playlists/2025-05-20_playlist_data.parquet')
df
# Out:
#                            playlist_id  \
# 0   PLoSWVnSA9vG8hI-SUpAimvYJrPh-PRRvp
# 1   PLoSWVnSA9vG_s-XT40oPKF0iWFGw8pOp2
# 2   PLoSWVnSA9vG8SK6-_45PAu6RVTaP1zXHf
# 3   PLoSWVnSA9vG_PuIrGMfUtJ2wwKSUb2CFd
# 4   PLoSWVnSA9vG9hJNdgr-81MG59EYT9eEYn
# ..                                 ...
# 62  PLT1rvk7Trkw6-eCetnOs60kLGdmcHhyj0
# 63  PLT1rvk7Trkw6dKQ_e0lgcKK93zy8dG3IV
# 64  PLT1rvk7Trkw7vHcabOEh79NphGB8KNhbf
# 65  PLT1rvk7Trkw4splKgiyKnQXGmLXPV1lMA
# 66                  PL97977A770B5B12E2
#
#                                      playlist_title                channel_id  \
# 0                                       Stay to Win  UCX6OQ3DkcsbYNE6H8uQQuVA
# 1                                      Philanthropy  UCX6OQ3DkcsbYNE6H8uQQuVA
# 2                                            7 Days  UCX6OQ3DkcsbYNE6H8uQQuVA
# 3                                         $1 vs $$$  UCX6OQ3DkcsbYNE6H8uQQuVA
# 4                              Most Popular Uploads  UCX6OQ3DkcsbYNE6H8uQQuVA
# ...

# %%
df = pd.read_parquet('data/channels/2025-05-20_channel_data.parquet')
df
# Out:
#                  channel_id                channel_name subscribers  \
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA                     MrBeast   396000000
# 1  UC4-79UOlP48-QNGgCko5p2g                   MrBeast 2    50000000
# 2  UCbCmjCuTUZos6Inko4u57UQ  Cocomelon - Nursery Rhymes   193000000
#
#     total_views video_count
# 0   83186134666         871
# 1    6892465570         135
# 2  201981039262        1545

# %%
channel_df = pd.read_csv('data/channels/2025-05-21_channel_data.csv')
channel_df
# Out:
#                  channel_id                channel_name  subscribers  \
# 0  UCX6OQ3DkcsbYNE6H8uQQuVA                     MrBeast    397000000
# 1  UC4-79UOlP48-QNGgCko5p2g                   MrBeast 2     50100000
# 2  UCbCmjCuTUZos6Inko4u57UQ  Cocomelon - Nursery Rhymes    193000000
# 3  UCk8GzjMOrta8yxDcKfylJYw           ✿ Kids Diana Show    134000000
# 4  UCRijo3ddMTht_IHyNSNXpNQ                Dude Perfect     61100000
#
#     total_views  video_count
# 0   83275820472          872
# 1    6897538138          135
# 2  201981039262         1546
# 3  115273125176         1357
# 4   18929490632          487

# %%
channel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel_id    5 non-null      object
#  1   channel_name  5 non-null      object
#  2   subscribers   5 non-null      int64
#  3   total_views   5 non-null      int64
#  4   video_count   5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
playlist_df = pd.read_csv('data/playlists/2025-05-21_playlist_data.csv')
playlist_df
# Out:
#                             playlist_id                      playlist_title  \
# 0    PLoSWVnSA9vG8hI-SUpAimvYJrPh-PRRvp                         Stay to Win
# 1    PLoSWVnSA9vG_s-XT40oPKF0iWFGw8pOp2                        Philanthropy
# 2    PLoSWVnSA9vG8SK6-_45PAu6RVTaP1zXHf                              7 Days
# 3    PLoSWVnSA9vG_PuIrGMfUtJ2wwKSUb2CFd                           $1 vs $$$
# 4    PLoSWVnSA9vG9hJNdgr-81MG59EYT9eEYn                Most Popular Uploads
# ..                                  ...                                 ...
# 137                  PLBAC78F58C8F9ABFC  World Record Shots by Dude Perfect
# 138                  PL3DADD3B0B6FD5E53          Dude Perfect in the Media!
# 139                  PLF628275CD5BFC6A9                 Dude Perfect™ Panda
# 140                  PL78596A4F8E36D8D9   Most Popular Dude Perfect Videos!
# 141            FLRijo3ddMTht_IHyNSNXpNQ                           Favorites
#
#                    channel_id  video_count
# ...

# %%
playlist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   playlist_id     142 non-null    object
#  1   playlist_title  142 non-null    object
#  2   channel_id      142 non-null    object
#  3   video_count     142 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 4.6+ KB

# %%
video_df = pd.read_csv('data/videos/2025-05-21_video_data.csv')
video_df
# Out:
#           video_id                                       video_title  \
# 0      UPrkC1LdlLY  Survive 100 Days In Nuclear Bunker, Win $500,000
# 1      U_LlX4t0A9I   $10,000 Every Day You Survive In The Wilderness
# 2      9RhWXPcKBI8            Survive 100 Days Trapped, Win $500,000
# 3      tnTPaLOaHz8  $10,000 Every Day You Survive In A Grocery Store
# 4      SM66GDRyIVY                  I Helped 2,000 People Walk Again
# ...            ...                                               ...
# 88987  jJBmQsIJjx8                      Ranch Edition | Dude Perfect
# 88988  8sE7gf5Zde0                          AMAZING BASKETBALL SHOTS
# 88989  oh44JbkH5rs           Amazing basketball shot home-made vol 2
# 88990  PD6eQY7yCfw  Dude Perfect | Backyard Edition | Our 1st Video!
# 88991  mWGA_yTpwQ0            Aggie Skates Off Roof  | Dude Perfect™
#
#              published_date      views    likes  comments  \
# 0      2024-08-03T16:00:00Z  284947338  5917108     86184
# ...

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88992 entries, 0 to 88991
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        88992 non-null  object
#  1   video_title     88992 non-null  object
#  2   published_date  88992 non-null  object
#  3   views           88992 non-null  int64
#  4   likes           88992 non-null  int64
#  5   comments        88992 non-null  int64
#  6   playlist_id     88992 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.8+ MB

# %%
video_df['published_date'] = pd.to_datetime(video_df['published_date'], errors='coerce', utc=True)
video_df
# Out:
#           video_id                                       video_title  \
# 0      UPrkC1LdlLY  Survive 100 Days In Nuclear Bunker, Win $500,000
# 1      U_LlX4t0A9I   $10,000 Every Day You Survive In The Wilderness
# 2      9RhWXPcKBI8            Survive 100 Days Trapped, Win $500,000
# 3      tnTPaLOaHz8  $10,000 Every Day You Survive In A Grocery Store
# 4      SM66GDRyIVY                  I Helped 2,000 People Walk Again
# ...            ...                                               ...
# 88987  jJBmQsIJjx8                      Ranch Edition | Dude Perfect
# 88988  8sE7gf5Zde0                          AMAZING BASKETBALL SHOTS
# 88989  oh44JbkH5rs           Amazing basketball shot home-made vol 2
# 88990  PD6eQY7yCfw  Dude Perfect | Backyard Edition | Our 1st Video!
# 88991  mWGA_yTpwQ0            Aggie Skates Off Roof  | Dude Perfect™
#
#                  published_date      views    likes  comments  \
# 0     2024-08-03 16:00:00+00:00  284947338  5917108     86184
# ...

# %%
video_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88992 entries, 0 to 88991
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   video_id        88992 non-null  object
#  1   video_title     88992 non-null  object
#  2   published_date  88992 non-null  datetime64[ns]
#  3   views           88992 non-null  int64
#  4   likes           88992 non-null  int64
#  5   comments        88992 non-null  int64
#  6   playlist_id     88992 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 4.8+ MB

# %%
video_df['published_date'] = video_df['published_date'].dt.tz_convert('America/New_York')
video_df
# Out:
#           video_id                                       video_title  \
# 0      UPrkC1LdlLY  Survive 100 Days In Nuclear Bunker, Win $500,000
# 1      U_LlX4t0A9I   $10,000 Every Day You Survive In The Wilderness
# 2      9RhWXPcKBI8            Survive 100 Days Trapped, Win $500,000
# 3      tnTPaLOaHz8  $10,000 Every Day You Survive In A Grocery Store
# 4      SM66GDRyIVY                  I Helped 2,000 People Walk Again
# ...            ...                                               ...
# 88987  jJBmQsIJjx8                      Ranch Edition | Dude Perfect
# 88988  8sE7gf5Zde0                          AMAZING BASKETBALL SHOTS
# 88989  oh44JbkH5rs           Amazing basketball shot home-made vol 2
# 88990  PD6eQY7yCfw  Dude Perfect | Backyard Edition | Our 1st Video!
# 88991  mWGA_yTpwQ0            Aggie Skates Off Roof  | Dude Perfect™
#
#                  published_date      views    likes  comments  \
# 0     2024-08-03 12:00:00-04:00  284947338  5917108     86184
# ...

# %%
video_df['published_date'] = video_df['published_date'].dt.tz_localize(None)
video_df
# Out:
#           video_id                                       video_title  \
# 0      UPrkC1LdlLY  Survive 100 Days In Nuclear Bunker, Win $500,000
# 1      U_LlX4t0A9I   $10,000 Every Day You Survive In The Wilderness
# 2      9RhWXPcKBI8            Survive 100 Days Trapped, Win $500,000
# 3      tnTPaLOaHz8  $10,000 Every Day You Survive In A Grocery Store
# 4      SM66GDRyIVY                  I Helped 2,000 People Walk Again
# ...            ...                                               ...
# 88987  jJBmQsIJjx8                      Ranch Edition | Dude Perfect
# 88988  8sE7gf5Zde0                          AMAZING BASKETBALL SHOTS
# 88989  oh44JbkH5rs           Amazing basketball shot home-made vol 2
# 88990  PD6eQY7yCfw  Dude Perfect | Backyard Edition | Our 1st Video!
# 88991  mWGA_yTpwQ0            Aggie Skates Off Roof  | Dude Perfect™
#
#            published_date      views    likes  comments  \
# 0     2024-08-03 12:00:00  284947338  5917108     86184
# ...

# %%
video_df['published_date'] = video_df['published_date'].dt.strftime('%Y-%m-%d %H:%M:%S')
video_df
# Out:
#           video_id                                       video_title  \
# 0      UPrkC1LdlLY  Survive 100 Days In Nuclear Bunker, Win $500,000
# 1      U_LlX4t0A9I   $10,000 Every Day You Survive In The Wilderness
# 2      9RhWXPcKBI8            Survive 100 Days Trapped, Win $500,000
# 3      tnTPaLOaHz8  $10,000 Every Day You Survive In A Grocery Store
# 4      SM66GDRyIVY                  I Helped 2,000 People Walk Again
# ...            ...                                               ...
# 88987  jJBmQsIJjx8                      Ranch Edition | Dude Perfect
# 88988  8sE7gf5Zde0                          AMAZING BASKETBALL SHOTS
# 88989  oh44JbkH5rs           Amazing basketball shot home-made vol 2
# 88990  PD6eQY7yCfw  Dude Perfect | Backyard Edition | Our 1st Video!
# 88991  mWGA_yTpwQ0            Aggie Skates Off Roof  | Dude Perfect™
#
#             published_date      views    likes  comments  \
# 0      2024-08-03 16:00:00  284947338  5917108     86184
# ...
